# %%
import os
import random

import matplotlib.pyplot as plt
import numpy as np
import torch

from PIL import Image

# %%
from model import Generator

# %%
# Setting manual seed for reproducibility
manual_seed = 999
random.seed(manual_seed)
print(f"Random Seed: {manual_seed}")
torch.manual_seed(manual_seed)
# Out:
# Random Seed: 999

# %%
# %matplotlib inline

print(os.listdir("../data/chest_xray - Copy/chest_xray/"))
# Out:
# ['.DS_Store', 'augmented', 'normal', 'test', 'train', 'val']

# %%
datadir = "../data/chest_xray - Copy/chest_xray/"

traindir = f"{datadir}train/"
testdir = f"{datadir}test/"
validdir = f"{datadir}val/"

# %%
BATCH_SIZE = 128
NUM_GPU = torch.cuda.device_count() if torch.cuda.is_available() else 0

device = torch.device("cuda:0" if NUM_GPU else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
noise_dimension = 100
image_shape = (3, 128, 128)
num_classes = 2
embedding_dim = BATCH_SIZE
features_g = 32
ngpu = 2

# %%
generator = Generator(
    noise_dimension, image_shape, num_classes, embedding_dim, features_g, ngpu
)
generator.load_state_dict(torch.load('generator.pth'))
generator.eval()
# print(generator)

x = torch.randn(1, noise_dimension, 1, 1)
y = torch.randint(0, num_classes, (1,))

print(f"{x.shape=}")
print(f"{y.shape=}, {y}")
print(f"{y=}")

assert generator(x, y).shape == (1, 3, 128, 128)
print(f"{generator(x, y).shape=}")

with torch.no_grad():
    result = generator(x, y)
    result = result[0].permute(1, 2, 0) * 0.5 + 0.5
    print(f"{result.shape}")
    # for item in result[0]:
    plt.imshow(result, cmap='gray')
    plt.show()
# Out:
# x.shape=torch.Size([1, 100, 1, 1])
# y.shape=torch.Size([1]), tensor([0])
# y=tensor([0])
# generator(x, y).shape=torch.Size([1, 3, 128, 128])
# torch.Size([128, 128, 3])

# %%
x = torch.randn(2, noise_dimension, 1, 1)
y = torch.zeros(2, dtype=torch.int64)

print(f"{y.shape=}, {y}")

with torch.no_grad():
    result = generator(x, y)
    print(f"{result.shape=}")
    for item in result:
        img =item.permute(1, 2, 0) * 0.5 + 0.5
        print(f"{img.shape}")
        # for item in result[0]:
        plt.imshow(img, cmap='gray')
        plt.show()
# Out:
# y.shape=torch.Size([2]), tensor([0, 0])
# result.shape=torch.Size([2, 3, 128, 128])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])

# %% [markdown]
# ## Normal Image Save

# %%
num_img = 128
x = torch.randn(num_img, noise_dimension, 1, 1)
y = torch.zeros(num_img, dtype=torch.int64)

print(f"{y.shape=}")

with torch.no_grad():
    result = generator(x, y)
    print(f"{result.shape=}")
    for idx, item in enumerate(result):
        img =item.permute(1, 2, 0) * 0.5 + 0.5
        # print(f"{img.shape}")
        # plt.imshow(img, cmap='gray')
        # plt.show()
        
        img = Image.fromarray(np.uint8(img.numpy() * 255))
        img.save(f"{datadir}normal/{idx}.png")
        print(f"Image saved - {idx}.png")
# Out:
# y.shape=torch.Size([128])
# result.shape=torch.Size([128, 3, 128, 128])
# Image saved - 0.png
# Image saved - 1.png
# Image saved - 2.png
# Image saved - 3.png
# Image saved - 4.png
# Image saved - 5.png
# Image saved - 6.png
# Image saved - 7.png
# Image saved - 8.png
# Image saved - 9.png
# Image saved - 10.png
# Image saved - 11.png
# Image saved - 12.png
# Image saved - 13.png
# Image saved - 14.png
# Image saved - 15.png
# Image saved - 16.png
# Image saved - 17.png
# Image saved - 18.png
# Image saved - 19.png
# Image saved - 20.png
# Image saved - 21.png
# Image saved - 22.png
# Image saved - 23.png
# Image saved - 24.png
# Image saved - 25.png
# Image saved - 26.png
# Image saved - 27.png
# Image saved - 28.png
# Image saved - 29.png
# Image saved - 30.png
# Image saved - 31.png
# Image saved - 32.png
# Image saved - 33.png
# Image saved - 34.png
# Image saved - 35.png
# Image saved - 36.png
# Image saved - 37.png
# Image saved - 38.png
# Image saved - 39.png
# Image saved - 40.png
# Image saved - 41.png
# Image saved - 42.png
# Image saved - 43.png
# Image saved - 44.png
# Image saved - 45.png
# Image saved - 46.png
# Image saved - 47.png
# Image saved - 48.png
# Image saved - 49.png
# Image saved - 50.png
# Image saved - 51.png
# Image saved - 52.png
# Image saved - 53.png
# Image saved - 54.png
# Image saved - 55.png
# Image saved - 56.png
# Image saved - 57.png
# Image saved - 58.png
# Image saved - 59.png
# Image saved - 60.png
# Image saved - 61.png
# Image saved - 62.png
# Image saved - 63.png
# Image saved - 64.png
# Image saved - 65.png
# Image saved - 66.png
# Image saved - 67.png
# Image saved - 68.png
# Image saved - 69.png
# Image saved - 70.png
# Image saved - 71.png
# Image saved - 72.png
# Image saved - 73.png
# Image saved - 74.png
# Image saved - 75.png
# Image saved - 76.png
# Image saved - 77.png
# Image saved - 78.png
# Image saved - 79.png
# Image saved - 80.png
# Image saved - 81.png
# Image saved - 82.png
# Image saved - 83.png
# Image saved - 84.png
# Image saved - 85.png
# Image saved - 86.png
# Image saved - 87.png
# Image saved - 88.png
# Image saved - 89.png
# Image saved - 90.png
# Image saved - 91.png
# Image saved - 92.png
# Image saved - 93.png
# Image saved - 94.png
# Image saved - 95.png
# Image saved - 96.png
# Image saved - 97.png
# Image saved - 98.png
# Image saved - 99.png
# Image saved - 100.png
# Image saved - 101.png
# Image saved - 102.png
# Image saved - 103.png
# Image saved - 104.png
# Image saved - 105.png
# Image saved - 106.png
# Image saved - 107.png
# Image saved - 108.png
# Image saved - 109.png
# Image saved - 110.png
# Image saved - 111.png
# Image saved - 112.png
# Image saved - 113.png
# Image saved - 114.png
# Image saved - 115.png
# Image saved - 116.png
# Image saved - 117.png
# Image saved - 118.png
# Image saved - 119.png
# Image saved - 120.png
# Image saved - 121.png
# Image saved - 122.png
# Image saved - 123.png
# Image saved - 124.png
# Image saved - 125.png
# Image saved - 126.png
# Image saved - 127.png

# %% [markdown]
# ## Pneumonia Image Save

# %%
num_img = 128
x = torch.randn(num_img, noise_dimension, 1, 1)
y = torch.ones(num_img, dtype=torch.int64)

print(f"{y.shape=}")

with torch.no_grad():
    result = generator(x, y)
    print(f"{result.shape=}")
    for idx, item in enumerate(result):
        img =item.permute(1, 2, 0) * 0.5 + 0.5
        # print(f"{img.shape}")
        # plt.imshow(img, cmap='gray')
        # plt.show()
        
        img = Image.fromarray(np.uint8(img.numpy() * 255))
        img.save(f"{datadir}augmented/{idx}.png")
        print(f"Image saved - {idx}.png")
# Out:
# y.shape=torch.Size([128])
# result.shape=torch.Size([128, 3, 128, 128])
# Image saved - 0.png
# Image saved - 1.png
# Image saved - 2.png
# Image saved - 3.png
# Image saved - 4.png
# Image saved - 5.png
# Image saved - 6.png
# Image saved - 7.png
# Image saved - 8.png
# Image saved - 9.png
# Image saved - 10.png
# Image saved - 11.png
# Image saved - 12.png
# Image saved - 13.png
# Image saved - 14.png
# Image saved - 15.png
# Image saved - 16.png
# Image saved - 17.png
# Image saved - 18.png
# Image saved - 19.png
# Image saved - 20.png
# Image saved - 21.png
# Image saved - 22.png
# Image saved - 23.png
# Image saved - 24.png
# Image saved - 25.png
# Image saved - 26.png
# Image saved - 27.png
# Image saved - 28.png
# Image saved - 29.png
# Image saved - 30.png
# Image saved - 31.png
# Image saved - 32.png
# Image saved - 33.png
# Image saved - 34.png
# Image saved - 35.png
# Image saved - 36.png
# Image saved - 37.png
# Image saved - 38.png
# Image saved - 39.png
# Image saved - 40.png
# Image saved - 41.png
# Image saved - 42.png
# Image saved - 43.png
# Image saved - 44.png
# Image saved - 45.png
# Image saved - 46.png
# Image saved - 47.png
# Image saved - 48.png
# Image saved - 49.png
# Image saved - 50.png
# Image saved - 51.png
# Image saved - 52.png
# Image saved - 53.png
# Image saved - 54.png
# Image saved - 55.png
# Image saved - 56.png
# Image saved - 57.png
# Image saved - 58.png
# Image saved - 59.png
# Image saved - 60.png
# Image saved - 61.png
# Image saved - 62.png
# Image saved - 63.png
# Image saved - 64.png
# Image saved - 65.png
# Image saved - 66.png
# Image saved - 67.png
# Image saved - 68.png
# Image saved - 69.png
# Image saved - 70.png
# Image saved - 71.png
# Image saved - 72.png
# Image saved - 73.png
# Image saved - 74.png
# Image saved - 75.png
# Image saved - 76.png
# Image saved - 77.png
# Image saved - 78.png
# Image saved - 79.png
# Image saved - 80.png
# Image saved - 81.png
# Image saved - 82.png
# Image saved - 83.png
# Image saved - 84.png
# Image saved - 85.png
# Image saved - 86.png
# Image saved - 87.png
# Image saved - 88.png
# Image saved - 89.png
# Image saved - 90.png
# Image saved - 91.png
# Image saved - 92.png
# Image saved - 93.png
# Image saved - 94.png
# Image saved - 95.png
# Image saved - 96.png
# Image saved - 97.png
# Image saved - 98.png
# Image saved - 99.png
# Image saved - 100.png
# Image saved - 101.png
# Image saved - 102.png
# Image saved - 103.png
# Image saved - 104.png
# Image saved - 105.png
# Image saved - 106.png
# Image saved - 107.png
# Image saved - 108.png
# Image saved - 109.png
# Image saved - 110.png
# Image saved - 111.png
# Image saved - 112.png
# Image saved - 113.png
# Image saved - 114.png
# Image saved - 115.png
# Image saved - 116.png
# Image saved - 117.png
# Image saved - 118.png
# Image saved - 119.png
# Image saved - 120.png
# Image saved - 121.png
# Image saved - 122.png
# Image saved - 123.png
# Image saved - 124.png
# Image saved - 125.png
# Image saved - 126.png
# Image saved - 127.png
